# %%
import pandas as pd

# %%
daum = pd.read_csv("../data/KP_daum_monthlyTop800_body.csv")

# %%
daum.drop("Unnamed: 0", axis = 1).drop_duplicates()
# Out:
#                                             0  \
# 0      https://v.daum.net/v/20180105100954077
# 1      https://v.daum.net/v/20180105164004067
# 2      https://v.daum.net/v/20180105101958491
# 3      https://v.daum.net/v/20180105173046721
# 4      https://v.daum.net/v/20180105084208085
# ...                                       ...
# 18382  https://v.daum.net/v/20221230105630139
# 18383  https://v.daum.net/v/20221230071650319
# 18384  https://v.daum.net/v/20221230052321943
# 18385  https://v.daum.net/v/20221228120203288
# 18386  https://v.daum.net/v/20221230091108475
#
#                                        1  \
# 0      카카오페이 오프라인 확장..'카카오페이 카드' 10일 나온다
# 1                            카카오페이 카드 출시
# 2                카카오페이, 체크카드 출시..오프라인 진출
# 3                  오프라인 결제 '카카오페이 카드' 출시
# 4              '카카오페이 카드' 출시.. 다양한 혜택 제공
# ...                                  ...
# 18382        파리바게뜨, 새해 1월 ‘파바데이’ 프로모션 진행
# 18383  용인시, 청년 전세보증금 반환보증 보증료 최대 30만원 지원
# ...

# %%
daum_comments = pd.read_csv("../data/KP_daum_comments_monthlyTop800.csv")

# %%
daum_comments.drop("Unnamed: 0", axis = 1).drop_duplicates()
# Out:
#               id     userId     postId  forumId  parentId     type status  \
# 0      203773412    3580467   27771481      -99         0  COMMENT      S
# 1      204026330 -556963703   27781199      -99         0  COMMENT      S
# 2      204203354  -30523365   27806152      -99         0  COMMENT      S
# 3      204592776   -8816213   27849284      -99         0  COMMENT      S
# 4      204595953  -10275396   27849284      -99         0  COMMENT      S
# ...          ...        ...        ...      ...       ...      ...    ...
# 71387  839646885   71407268  174443823      -99         0  COMMENT      S
# 71388  840302923  -98134365  174552834      -99         0  COMMENT      S
# 71389  840296870  -64074345  174552834      -99         0  COMMENT      S
# 71390  840276196    4010993  174552834      -99         0  COMMENT      S
# 71391  840301750   22995969  174552834      -99         0  COMMENT      S
#
#        flags  rating         icon  \
# 0        256       0  4411172:2:4
# ...
