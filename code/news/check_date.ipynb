# %%
import pandas as pd

# %%
news_comments = pd.read_csv("../../data/news_comments_date.csv")

# %%
news_comments
# Out:
#         Unnamed: 0                                                url  \
# 0                0  https://n.news.naver.com/mnews/article/comment...
# 1                1  https://n.news.naver.com/mnews/article/comment...
# 2                2  https://n.news.naver.com/mnews/article/comment...
# 3                3  https://n.news.naver.com/mnews/article/comment...
# 4                4  https://n.news.naver.com/mnews/article/comment...
# ...            ...                                                ...
# 411984       71387             https://v.daum.net/v/20221226050109898
# 411985       71388             https://v.daum.net/v/20221229172340151
# 411986       71389             https://v.daum.net/v/20221229172340151
# 411987       71390             https://v.daum.net/v/20221229172340151
# 411988       71391             https://v.daum.net/v/20221229172340151
#
#                                                      text         ymd
# ...
