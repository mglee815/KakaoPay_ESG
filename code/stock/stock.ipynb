# %%
import pandas_datareader.data as pdr
import matplotlib.pyplot as plt

df_pdr = pdr.DataReader('377300', 'naver', start='2019-01-01', end='2023-02-20')
df_pdr['Close'] = df_pdr['Close'].apply(lambda x : int(x))

# %%
plt.plot(df_pdr['Close'])

# %%
df_pdr.to_csv("../../data/time series/카카오페이 주식 ts.csv")
